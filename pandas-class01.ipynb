# %%
import pandas as pd
data = pd.read_csv("netflix.csv")
data.head(n=10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
data.shape
# Out:
# (8807, 12)

# %%
data.loc[(data.rating=="PG-13") & (data.release_year==2020)]
# Out:
#      show_id   type                                            title  \
# 0         s1  Movie                             Dick Johnson Is Dead
# 774     s775  Movie                                         2 Hearts
# 1366   s1367  Movie                                           Fatima
# 1484   s1485  Movie                                 Cops and Robbers
# 1499   s1500  Movie                                 The Midnight Sky
# 1550   s1551  Movie                           A California Christmas
# 1558   s1559  Movie                                     Giving Voice
# 1560   s1561  Movie                                         The Prom
# 1705   s1706  Movie                                   The Life Ahead
# 1814   s1815  Movie                                          Rebecca
# 1816   s1817  Movie                         Tremors: Shrieker Island
# 1879   s1880  Movie                                  Hubie Halloween
# 1900   s1901  Movie                           Vampires vs. the Bronx
# ...

# %%
data.loc[(data.duration == "90 min"),['title','description']]
# Out:
#                                 title  \
# 0                Dick Johnson Is Dead
# 94                          Show Dogs
# 107                  A Champion Heart
# 229                      The Old Ways
# 283              Misha and the Wolves
# ...                               ...
# 8651                            Tyson
# 8655             Unaccompanied Minors
# 8670                    Vantage Point
# 8735  Who's That Knocking at My Door?
# 8776                       Yellowbird
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 94    A rough and tough police dog must go undercove...
# 107   When a grieving teen must work off her debt to...
# 229   A reporter visits her birthplace in Veracruz f...
# 283   As a little girl, she escaped the Holocaust an...
# ...                                                 ...
# 8651  In this surprisingly emotional documentary, he...
# ...

# %%
data.describe(n=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-98706a8de618> in <module>
# ----> 1 data.describe(n=10)
#
# TypeError: describe() got an unexpected keyword argument 'n'

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64
